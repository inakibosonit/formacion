# %% [markdown]
# Aplicar no solo count (para obtener el número de líneas) y show sino probar distintas sobrecargas del método show
# (con/sin truncate, indicando/sin indicar num de filas, etc) así como también los métodos, head, take, first (diferencias entre estos 3?)

# %% [markdown]
# importar las librerias de spark

# %%
import sys 
from pyspark.sql import SparkSession
from pyspark.sql.functions import count

# %%
quijote_path = "gs://bosonit_spark/archivos/el_quijote.txt"

spark = (SparkSession
.builder
.appName("QUIJOTE_TIME")
.getOrCreate())

quijote_df = spark.read.text(quijote_path)

# %% [markdown]
# Realizamos un show con truncate

# %%
quijote_df.show(truncate = True)
# Out:
# +--------------------+
# |               value|
# +--------------------+
# |DON QUIJOTE DE LA...|
# |Miguel de Cervant...|
# |                    |
# |       PRIMERA PARTE|
# |CAPÍTULO 1: Que ...|
# |En un lugar de la...|
# |Tuvo muchas veces...|
# |En resolución, e...|
# |historia más cie...|
# |Decía él, que e...|
# |En efecto, remata...|
# |Imaginábase el p...|
# |linaje y patria, ...|
# |Limpias, pues, su...|
# |Capítulo 2: Que ...|
# |Hechas, pues, est...|
# |Estos pensamiento...|
# |Con estos iba ens...|
# |Autores hay que d...|
# |muertos de hambre...|
# +--------------------+
# only showing top 20 rows

# %% [markdown]
# Realizamos un show sin truncate

# %%
quijote_df.show(truncate = False)
# Out:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
quijote_df.take(5)
# Out:
# [Row(value='DON QUIJOTE DE LA MANCHA'),
#  Row(value='Miguel de Cervantes Saavedra'),
#  Row(value=''),
#  Row(value='PRIMERA PARTE'),
#  Row(value='CAPÍTULO 1: Que trata de la condición y ejercicio del famoso hidalgo D. Quijote de la Mancha')]

# %%
quijote_df.first()
# Out:
# Row(value='DON QUIJOTE DE LA MANCHA')

# %%
quijote_df.head(5)
# Out:
# [Row(value='DON QUIJOTE DE LA MANCHA'),
#  Row(value='Miguel de Cervantes Saavedra'),
#  Row(value=''),
#  Row(value='PRIMERA PARTE'),
#  Row(value='CAPÍTULO 1: Que trata de la condición y ejercicio del famoso hidalgo D. Quijote de la Mancha')]
